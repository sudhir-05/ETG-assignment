# %% [markdown]
# ## **[IMP]**RUN this if records.json is missing to create an sample database
# ## **[WARNING]** This will override previous data

# %%
RECORD = {
        1 : {
            "ID": "1",
            "NAME": "NIKE",
            "TYPE": "TSHIRT",
            "QUANTITY": "12",
            "PRICE": "700",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        2 : {
            "ID": "2",
            "NAME": "NIKE",
            "TYPE": "TSHIRT",
            "QUANTITY": "16",
            "PRICE": "700",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        3 : {
            "ID": "3",
            "NAME": "NIKE",
            "TYPE": "TSHIRT",
            "QUANTITY": "15",
            "PRICE": "700",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        4 : {
            "ID": "4",
            "NAME": "NIKE",
            "TYPE": "PANTS",
            "QUANTITY": "10",
            "PRICE": "900",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        5 : {
            "ID": "5",
            "NAME": "NIKE",
            "TYPE": "PANTS",
            "QUANTITY": "4",
            "PRICE": "900",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        6 : {
            "ID": "6",
            "NAME": "NIKE",
            "TYPE": "PANTS",
            "QUANTITY": "20",
            "PRICE": "900",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        7 : {
            "ID": "7",
            "NAME": "ADIDAS",
            "TYPE": "TSHIRT",
            "QUANTITY": "15",
            "PRICE": "650",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        8 : {
            "ID": "8",
            "NAME": "ADIDAS",
            "TYPE": "TSHIRT",
            "QUANTITY": "16",
            "PRICE": "650",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        9 : {
            "ID": "9",
            "NAME": "ADIDAS",
            "TYPE": "TSHIRT",
            "QUANTITY": "16",
            "PRICE": "650",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        10 : {
            "ID": "10",
            "NAME": "ADIDAS",
            "TYPE": "PANTS",
            "QUANTITY": "12",
            "PRICE": "850",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        11 : {
            "ID": "11",
            "NAME": "ADIDAS",
            "TYPE": "PANTS",
            "QUANTITY": "15",
            "PRICE": "850",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        12 : {
            "ID": "12",
            "NAME": "ADIDAS",
            "TYPE": "PANTS",
            "QUANTITY": "6",
            "PRICE": "850",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        13 : {
            "ID": "13",
            "NAME": "PUMA",
            "TYPE": "TSHIRT",
            "QUANTITY": "2",
            "PRICE": "600",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        14 : {
            "ID": "14",
            "NAME": "PUMA",
            "TYPE": "TSHIRT",
            "QUANTITY": "4",
            "PRICE": "600",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        15 : {
            "ID": "15",
            "NAME": "PUMA",
            "TYPE": "TSHIRT",
            "QUANTITY": "15",
            "PRICE": "600",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        16 : {
            "ID": "16",
            "NAME": "PUMA",
            "TYPE": "PANTS",
            "QUANTITY": "8",
            "PRICE": "900",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        17 : {
            "ID": "17",
            "NAME": "PUMA",
            "TYPE": "PANTS",
            "QUANTITY": "4",
            "PRICE": "900",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        18 : {
            "ID": "18",
            "NAME": "PUMA",
            "TYPE": "PANTS",
            "QUANTITY": "5",
            "PRICE": "900",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        19 : {
            "ID": "19",
            "NAME": "HRX",
            "TYPE": "TSHIRT",
            "QUANTITY": "4",
            "PRICE": "500",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        20 : {
            "ID": "20",
            "NAME": "HRX",
            "TYPE": "TSHIRT",
            "QUANTITY": "6",
            "PRICE": "500",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        21 : {
            "ID": "21",
            "NAME": "HRX",
            "TYPE": "TSHIRT",
            "QUANTITY": "4",
            "PRICE": "500",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        22 : {
            "ID": "22",
            "NAME": "HRX",
            "TYPE": "PANTS",
            "QUANTITY": "5",
            "PRICE": "750",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        23 : {
            "ID": "23",
            "NAME": "HRX",
            "TYPE": "PANTS",
            "QUANTITY": "9",
            "PRICE": "750",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        24 : {
            "ID": "24",
            "NAME": "HRX",
            "TYPE": "PANTS",
            "QUANTITY": "10",
            "PRICE": "750",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        25 : {
            "ID": "25",
            "NAME": "REEBOK",
            "TYPE": "TSHIRT",
            "QUANTITY": "4",
            "PRICE": "550",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        26 : {
            "ID": "26",
            "NAME": "REEBOK",
            "TYPE": "TSHIRT",
            "QUANTITY": "6",
            "PRICE": "550",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        27 : {
            "ID": "27",
            "NAME": "REEBOK",
            "TYPE": "TSHIRT",
            "QUANTITY": "4",
            "PRICE": "550",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        },
        28 : {
            "ID": "28",
            "NAME": "REEBOK",
            "TYPE": "PANTS",
            "QUANTITY": "5",
            "PRICE": "800",
            "DISCOUNT": "8",
            "COLOR": "RED"
        },
        29 : {
            "ID": "29",
            "NAME": "REEBOK",
            "TYPE": "PANTS",
            "QUANTITY": "9",
            "PRICE": "800",
            "DISCOUNT": "7",
            "COLOR": "BLUE"
        },
        30 : {
            "ID": "30",
            "NAME": "REEBOK",
            "TYPE": "PANTS",
            "QUANTITY": "10",
            "PRICE": "800",
            "DISCOUNT": "6",
            "COLOR": "BLACK"
        }
}

import json
with open("records.json", "w") as outfile:
    json.dump(RECORD, outfile, indent=1)
    
sales = {
 "DummyData1": {
  "NIKE TSHIRT BLUE": 1,
  "Total": 651.0,
  "Name": "shubham v"
 },
 "DummyData2": {
  "PUMA PANTS RED": 2,
  "HRX PANTS BLACK": 1,
  "Total": 2361.0,
  "Name": "sudhir"
 }
}
import json
with open("sales.json", "w") as outfile2:
    json.dump(sales, outfile2, indent=1)
